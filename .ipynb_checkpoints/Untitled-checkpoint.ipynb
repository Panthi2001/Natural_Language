# %%
pip install nbimporter
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nbimporter
from data_preprocessing import processed_text

# Now you can use processed_text:
result = processed_text("Your sample text here")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 import nbimporter
# ----> 2 from data_preprocessing import processed_text
#       4 # Now you can use processed_text:
#       5 result = processed_text("Your sample text here")
#
# ModuleNotFoundError: No module named 'data_preprocessing'
