# %%
import data_preprocessing_module as dap
import pandas as pd

# %%
df =pd.read_csv('datasets/changed/data_news_features.csv')

# %%
df["title"] = df["title"].apply(dap.preprocess_text)

# %%
print(df["title"])
# Out:
# 0      anoth terrorist attack nycwhi still polit corr...
# 1          donald trump drug big factor charlott protest
# 2       obama un give liberti enhanc secur america video
# 3          trump vs clinton fundament clash economi work
# 4      presid obama veto victim bill set showdown con...
#                              ...
# 177      hillari top donor countri auction isi sex slave
# 178                   cavuto expos lester holt lie debat
# 179            ap said boy obama born particular countri
# 180                peopl notic someth odd hillari outfit
# 181    peopl notic someth odd hillari outfit debat la...
# Name: title, Length: 182, dtype: object
